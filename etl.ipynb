# %%
import pandas as pd

# Load CSVs with correct delimiter
shareprices_df = pd.read_csv("us-shareprices-daily.csv", sep=";")
companies_df = pd.read_csv("us-companies.csv", sep=";")
income_df = pd.read_csv("us-income-quarterly.csv", sep=";")

# Convert column names to lowercase
shareprices_df.columns = shareprices_df.columns.str.lower()
companies_df.columns = companies_df.columns.str.lower()
income_df.columns = income_df.columns.str.lower()

# Display initial data
print("📌 Raw Share Prices Data:")
display(shareprices_df.head())

print("📌 Raw Companies Data:")
display(companies_df.head())

print("📌 Raw Income Statements Data:")
display(income_df.head())
# Out:
# 📌 Raw Share Prices Data:
#   ticker  simfinid        date   open   high    low  close  adj. close  \
# 0      A     45846  2019-03-29  80.16  80.67  79.95  80.38       77.04
# 1      A     45846  2019-04-01  80.96  81.77  80.96  81.56       78.33
# 2      A     45846  2019-04-02  81.71  81.76  81.03  81.14       77.93
# 3      A     45846  2019-04-03  81.54  82.02  81.46  81.94       78.70
# 4      A     45846  2019-04-04  81.84  82.05  80.44  80.83       77.63
#
#     volume  dividend  shares outstanding
# 0  1585137       NaN         317515869.0
# 1  1522681      0.16         317515869.0
# 2  1203037       NaN         317515869.0
# 3  2141025       NaN         317515869.0
# 4  2180112       NaN         317515869.0
# 📌 Raw Companies Data:
#   ticker  simfinid company name  industryid isin  \
# 0    NaN  17162642          NaN         NaN  NaN
# 1    NaN  17429327          NaN         NaN  NaN
# 2    NaN  17590527          NaN         NaN  NaN
# 3    NaN  17590533          NaN         NaN  NaN
# 4    NaN  17596599          NaN         NaN  NaN
#
#    end of financial year (month)  number employees business summary market  \
# 0                            NaN               NaN              NaN     us
# 1                            NaN               NaN              NaN     us
# 2                            NaN               NaN              NaN     us
# 3                            NaN               NaN              NaN     us
# 4                            NaN               NaN              NaN     us
#
#          cik main currency
# 0  1913577.0           USD
# 1  1894951.0           USD
# 2  1847355.0           USD
# 3  1856161.0           USD
# 4  1862463.0           USD
# 📌 Raw Income Statements Data:
#   ticker  simfinid currency  fiscal year fiscal period report date  \
# 0      A     45846      USD         2019            Q2  2019-04-30
# 1      A     45846      USD         2019            Q3  2019-07-31
# 2      A     45846      USD         2019            Q4  2019-10-31
# 3      A     45846      USD         2020            Q1  2020-01-31
# 4      A     45846      USD         2020            Q2  2020-04-30
#
#   publish date restated date  shares (basic)  shares (diluted)  ...  \
# 0   2019-05-30    2019-05-30     317000000.0       321000000.0  ...
# 1   2019-08-30    2019-08-30     312000000.0       316000000.0  ...
# 2   2019-12-19    2019-08-30     309000000.0       313000000.0  ...
# 3   2020-03-03    2021-03-02     310000000.0       313000000.0  ...
# 4   2020-06-01    2021-06-01     309000000.0       312000000.0  ...
#
#    non-operating income (loss)  interest expense, net  \
# 0                    2000000.0             -7000000.0
# 1                   -3000000.0             -8000000.0
# 2                  -19000000.0            -15000000.0
# 3                    4000000.0            -17000000.0
# 4                   19000000.0            -17000000.0
#
#    pretax income (loss), adj.  abnormal gains (losses)  pretax income (loss)  \
# 0                 218000000.0                      NaN             218000000
# 1                 222000000.0                      NaN             222000000
# 2                 231000000.0                      NaN             231000000
# 3                 219000000.0                      NaN             219000000
# 4                 121000000.0                      NaN             121000000
#
#    income tax (expense) benefit, net  \
# 0                        -36000000.0
# 1                        -31000000.0
# 2                        -37000000.0
# 3                        -22000000.0
# 4                        -20000000.0
#
#    income (loss) from continuing operations  net extraordinary gains (losses)  \
# 0                                 182000000                               NaN
# 1                                 191000000                               NaN
# 2                                 194000000                               NaN
# 3                                 197000000                               NaN
# 4                                 101000000                               NaN
#
#    net income  net income (common)
# 0   182000000            182000000
# 1   191000000            191000000
# 2   194000000            194000000
# 3   197000000            197000000
# 4   101000000            101000000
#
# [5 rows x 28 columns]

# %%
# Convert 'date' column to datetime format
shareprices_df['date'] = pd.to_datetime(shareprices_df['date'], errors='coerce')

# Drop rows with missing values in essential columns
shareprices_df.dropna(subset=['ticker', 'close'], inplace=True)

# Convert numeric columns to float
price_columns = ['open', 'high', 'low', 'close', 'adj. close', 'volume']
for col in price_columns:
    if col in shareprices_df.columns:
        shareprices_df[col] = pd.to_numeric(shareprices_df[col], errors='coerce')

# Display after cleaning
print("✅ After Cleaning Share Prices Data:")
display(shareprices_df.head())
# Out:
# ✅ After Cleaning Share Prices Data:
#   ticker  simfinid       date   open   high    low  close  adj. close  \
# 0      A     45846 2019-03-29  80.16  80.67  79.95  80.38       77.04
# 1      A     45846 2019-04-01  80.96  81.77  80.96  81.56       78.33
# 2      A     45846 2019-04-02  81.71  81.76  81.03  81.14       77.93
# 3      A     45846 2019-04-03  81.54  82.02  81.46  81.94       78.70
# 4      A     45846 2019-04-04  81.84  82.05  80.44  80.83       77.63
#
#     volume  dividend  shares outstanding
# 0  1585137       NaN         317515869.0
# 1  1522681      0.16         317515869.0
# 2  1203037       NaN         317515869.0
# 3  2141025       NaN         317515869.0
# 4  2180112       NaN         317515869.0

# %%
# Merge stock prices with company information
merged_df = shareprices_df.merge(companies_df, on='ticker', how='left')

# Display after merging
print("✅ After Merging with Company Info:")
display(merged_df.head())
# Out:
# ✅ After Merging with Company Info:
#   ticker  simfinid_x       date   open   high    low  close  adj. close  \
# 0      A       45846 2019-03-29  80.16  80.67  79.95  80.38       77.04
# 1      A       45846 2019-04-01  80.96  81.77  80.96  81.56       78.33
# 2      A       45846 2019-04-02  81.71  81.76  81.03  81.14       77.93
# 3      A       45846 2019-04-03  81.54  82.02  81.46  81.94       78.70
# 4      A       45846 2019-04-04  81.84  82.05  80.44  80.83       77.63
#
#     volume  dividend  ...  simfinid_y              company name industryid  \
# 0  1585137       NaN  ...       45846  AGILENT TECHNOLOGIES INC   106001.0
# 1  1522681      0.16  ...       45846  AGILENT TECHNOLOGIES INC   106001.0
# 2  1203037       NaN  ...       45846  AGILENT TECHNOLOGIES INC   106001.0
# 3  2141025       NaN  ...       45846  AGILENT TECHNOLOGIES INC   106001.0
# 4  2180112       NaN  ...       45846  AGILENT TECHNOLOGIES INC   106001.0
#
#            isin end of financial year (month)  number employees  \
# 0  US00846U1016                          10.0           16400.0
# 1  US00846U1016                          10.0           16400.0
# 2  US00846U1016                          10.0           16400.0
# 3  US00846U1016                          10.0           16400.0
# 4  US00846U1016                          10.0           16400.0
#
#                                     business summary market        cik  \
# 0  Agilent Technologies Inc is engaged in life sc...     us  1090872.0
# 1  Agilent Technologies Inc is engaged in life sc...     us  1090872.0
# 2  Agilent Technologies Inc is engaged in life sc...     us  1090872.0
# 3  Agilent Technologies Inc is engaged in life sc...     us  1090872.0
# 4  Agilent Technologies Inc is engaged in life sc...     us  1090872.0
#
#    main currency
# 0            USD
# 1            USD
# 2            USD
# 3            USD
# 4            USD
#
# [5 rows x 21 columns]

# %%
merged_df["shares outstanding"].median()
# Out:
# np.float64(48730460.0)

# %%
# Fill missing values for 'dividend' with 0
merged_df['dividend'].fillna(0, inplace=True)

# Fill missing values for 'shares outstanding' with median
merged_df['shares outstanding'].fillna(merged_df['shares outstanding'].median(), inplace=True)


# Fill missing values for 'industryid' and 'ISIN'
merged_df['industryid'].fillna("Unknown Industry", inplace=True)
merged_df['isin'].fillna("Unknown", inplace=True)

# Drop non-essential columns with too many NaNs
merged_df.drop(columns=['business summary', 'number employees', 'cik'], inplace=True)

# Display after fixing missing values
print("✅ After Handling Missing Values:")
display(merged_df.head())
# Out:
# C:\Users\Samir\AppData\Local\Temp\ipykernel_16304\2031137744.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['dividend'].fillna(0, inplace=True)
# C:\Users\Samir\AppData\Local\Temp\ipykernel_16304\2031137744.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['shares outstanding'].fillna(merged_df['shares outstanding'].median(), inplace=True)
# C:\Users\Samir\AppData\Local\Temp\ipykernel_16304\2031137744.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['industryid'].fillna("Unknown Industry", inplace=True)
# C:\Users\Samir\AppData\Local\Temp\ipykernel_16304\2031137744.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown Industry' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   merged_df['industryid'].fillna("Unknown Industry", inplace=True)
# C:\Users\Samir\AppData\Local\Temp\ipykernel_16304\2031137744.py:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_df['isin'].fillna("Unknown", inplace=True)
# ✅ After Handling Missing Values:
#   ticker  simfinid_x       date   open   high    low  close  adj. close  \
# 0      A       45846 2019-03-29  80.16  80.67  79.95  80.38       77.04
# 1      A       45846 2019-04-01  80.96  81.77  80.96  81.56       78.33
# 2      A       45846 2019-04-02  81.71  81.76  81.03  81.14       77.93
# 3      A       45846 2019-04-03  81.54  82.02  81.46  81.94       78.70
# 4      A       45846 2019-04-04  81.84  82.05  80.44  80.83       77.63
#
#     volume  dividend  shares outstanding  simfinid_y  \
# 0  1585137      0.00         317515869.0       45846
# 1  1522681      0.16         317515869.0       45846
# 2  1203037      0.00         317515869.0       45846
# 3  2141025      0.00         317515869.0       45846
# 4  2180112      0.00         317515869.0       45846
#
#                company name industryid          isin  \
# 0  AGILENT TECHNOLOGIES INC   106001.0  US00846U1016
# 1  AGILENT TECHNOLOGIES INC   106001.0  US00846U1016
# 2  AGILENT TECHNOLOGIES INC   106001.0  US00846U1016
# 3  AGILENT TECHNOLOGIES INC   106001.0  US00846U1016
# 4  AGILENT TECHNOLOGIES INC   106001.0  US00846U1016
#
#    end of financial year (month) market main currency
# 0                           10.0     us           USD
# 1                           10.0     us           USD
# 2                           10.0     us           USD
# 3                           10.0     us           USD
# 4                           10.0     us           USD

# %% [markdown]
# print(merged_df.isnull().sum())  # Shows remaining missing values

# %%
# Check for remaining NaNs
print(merged_df.isnull().sum())  # Should show all 0s

# Save cleaned dataset
merged_df.to_csv("fully_cleaned_stock_data.csv", index=False)
print("✅ Final Cleaning Done! Data saved as fully_cleaned_stock_data.csv")
# Out:
# ticker                           0
# simfinid_x                       0
# date                             0
# open                             0
# high                             0
# low                              0
# close                            0
# adj. close                       0
# volume                           0
# dividend                         0
# shares outstanding               0
# simfinid_y                       0
# company name                     0
# industryid                       0
# isin                             0
# end of financial year (month)    0
# market                           0
# main currency                    0
# dtype: int64
# ✅ Final Cleaning Done! Data saved as fully_cleaned_stock_data.csv

# %%
# Count unique stock tickers
num_stocks = merged_df["ticker"].nunique()

print(f"📈 Number of Unique Stocks in Dataset: {num_stocks}")
# Out:
# 📈 Number of Unique Stocks in Dataset: 5550

# %%
# Check the shape of the DataFrame
print("📊 Shape of the DataFrame:")
print(merged_df.shape)  # Prints the number of rows and columns
# Out:
# 📊 Shape of the DataFrame:
# (5768313, 18)

# %%
# Find the top 5 stocks with the most data
top_5_stocks = merged_df["ticker"].value_counts().head(5).index.tolist()
print("📌 Top 5 Most Traded Stocks:", top_5_stocks)
# Out:
# 📌 Top 5 Most Traded Stocks: ['ZYXI', 'A', 'AA', 'ZYME', 'ZWS']

# %%
# Step 1: Identify the Top 5 Most Traded Stocks
top_5_stocks = merged_df["ticker"].value_counts().head(5).index.tolist()
print("📌 Top 5 Most Traded Stocks:", top_5_stocks)

# Step 2: Filter the Dataset to Only These 5 Stocks
filtered_df = merged_df[merged_df["ticker"].isin(top_5_stocks)]

# Check the new shape
print("📊 New Shape of Filtered Data:", filtered_df.shape)

# Save the reduced dataset
filtered_df.to_csv("filtered_stock_data.csv", index=False)
print("✅ Filtered data saved as 'filtered_stock_data.csv'")
# Out:
# 📌 Top 5 Most Traded Stocks: ['ZYXI', 'A', 'AA', 'ZYME', 'ZWS']
# 📊 New Shape of Filtered Data: (6200, 18)
# ✅ Filtered data saved as 'filtered_stock_data.csv'
